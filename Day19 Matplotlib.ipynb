# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
plt.title('Plot')
plt.plot([1,4,9,16])
plt.show()

# %%
plt.title('x ticks')
plt.plot([10,20,30,40],[1,4,9,16])
plt.show()

# %%
plt.title('Plot')
plt.plot([1,4,9,16])

# %%
plt.title('한글 제목')
plt.plot([10,20,30,40],[1,4,9,16])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44544 (\N{HANGUL SYLLABLE GEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 시스템 폰트 경로 리스트
font_list = mpl.font_manager.findSystemFonts()
print(font_list)
# Out:
# ['C:\\Windows\\Fonts\\TCCB____.TTF', 'C:\\Windows\\Fonts\\BOD_BLAR.TTF', 'C:\\Windows\\Fonts\\COLONNA.TTF', 'C:\\Windows\\Fonts\\Inkfree.ttf', 'C:\\Windows\\Fonts\\ariali.ttf', 'C:\\Windows\\Fonts\\LTYPE.TTF', 'C:\\Windows\\Fonts\\FZYTK.TTF', 'C:\\Windows\\Fonts\\REFSPCL.TTF', 'C:\\Windows\\Fonts\\GARA.TTF', 'C:\\Windows\\Fonts\\constan.ttf', 'C:\\Windows\\Fonts\\GOUDYSTO.TTF', 'C:\\Windows\\Fonts\\CENTURY.TTF', 'C:\\Windows\\Fonts\\HMFMPYUN.TTF', 'C:\\Windows\\Fonts\\georgiaz.ttf', 'C:\\Windows\\Fonts\\ONYX.TTF', 'C:\\Windows\\Fonts\\ntailub.ttf', 'C:\\Windows\\Fonts\\constani.ttf', 'C:\\Windows\\Fonts\\GOUDOS.TTF', 'C:\\Windows\\Fonts\\PERTILI.TTF', 'C:\\Windows\\Fonts\\CALIST.TTF', 'C:\\Windows\\Fonts\\BOD_B.TTF', 'C:\\Windows\\Fonts\\H2GPRM.TTF', 'C:\\Windows\\Fonts\\POORICH.TTF', 'C:\\Windows\\Fonts\\NIAGSOL.TTF', 'C:\\Windows\\Fonts\\LeelaUIb.ttf', 'C:\\Windows\\Fonts\\LHANDW.TTF', 'C:\\Windows\\Fonts\\CENSCBK.TTF', 'C:\\Windows\\Fonts\\seguili.ttf', 'C:\\Windows\\Fonts\\comicb
# ...

# %%
# 폰트 설정하기
prop = mpl.font_manager.FontProperties(fname='원하는 폰트 경로')
plt.rcParams['font.family'] = prop.get_family()

# %%
# 폰트 설정하기
prop = mpl.font_manager.FontProperties(fname='원하는 폰트 경로')
plt.rcParams['font.family'] = prop.get_family()

# %%
# %pwd
# Out:
# 'C:\\python'

# %%
import matplotlib as mpl
# Add every font at the specified location
font_dir = ['./fonts']
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname=font).get_name())
    mpl.font_manager.fontManager.addfont(font)
# Out:
# NanumMyeongjo
# Noto Sans KR
# Noto Sans KR
# Noto Sans KR
# Noto Sans KR
# Noto Serif KR
# Noto Sans KR
# Noto Serif KR
# NanumMyeongjo
# NanumMyeongjo
# Noto Sans KR
# Noto Sans KR
# Noto Serif KR
# Black Han Sans
# NanumGothic
# Noto Serif KR
# Noto Sans KR
# Noto Sans KR
# Noto Serif KR
# Noto Sans KR
# NanumGothic
# Noto Sans KR
# Noto Sans KR
# Noto Serif KR
# NanumGothic
# Noto Serif KR

# %%
# Set font family globally
mpl.rcParams['font.family'] = 'Noto Sans KR'
print(mpl.rcParams['font.family'])
# Out:
# ['Noto Sans KR']

# %%
plt.title('한글')
plt.plot(range(1,5))
plt.show()

# %%
plt.title('한글')
plt.plot([10,20,30,40],[1,4,9,16])
plt.xlabel('x축 레이블')
plt.ylabel('y축 레이블')
plt.show()

# %%
title_font = {'family': 'Noto Serif KR',
              'size': 24,
              'color': 'black'}
xlabel_font = {'family': 'Noto Serif KR',
               'size': 18,
               'weight': 'bold',
               'color': 'darkred'}
ylabel_font = {'family': 'NanumGothic',
               'size': 12,
               'weight': 'light',
               'color': 'blue'}

plt.title('한글', fontdict=title_font)
plt.plot([10,20,30,40],[1,4,9,16])
plt.xlabel('x축 레이블', fontdict=xlabel_font)
plt.ylabel('y축 레이블', fontdict=ylabel_font)
plt.show()

# %%
# -(마이너스) 안 깨지게 설정
mpl.rc('axes', unicode_minus=False)

# %%
plt.title("'rs--' 스타일의 plot")
plt.plot([10,20,30,40],[1,4,9,16],'mp--')
plt.show()

# %%
plt.title('스타일의 적용 예')
plt.plot([10,20,30,40],[1,4,9,16], c='b',
         lw=5, ls='--', marker='o', ms=15, mec='g', mew=5, mfc='r')
plt.show()

# %%
plt.title('x축, y축의 범위 설정')
plt.plot([10,20,30,40],[1,4,9,16],
         c='b', lw=5, ls='--', marker='o', ms=15, mec='g', mew=5, mfc='r')
plt.xlim(0,50)
plt.ylim(-10,30)
plt.show()

# %%
import numpy as np
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title("x축과 y축의 tick label 설정")
plt.plot(X, C)
plt.xticks ([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
plt.yticks ([-1, 0, +1])
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos (X)
plt.title("Tex, 문자열로 tick label 정의")
plt.plot(X, C)
plt.xticks ([-np.pi, -np.pi / 2, 0, np.pi/2, np.pi],
            [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks ([-1, 0, 1], ["Low", "Zero", "High"])
plt.show()

# %%
t = np.arange (0., 5., 0.2)
plt.title("라인 플롯에서 여러개의 선 그리기")
plt.plot(t, t, 'r--', t, 0.5 * t**2, 'bs:',t, 0.2 * t**3, 'g^-')
plt.show()

# %%
plt.title("복수의 plot 명령을 한 그림에서 표현")
stylel = {"c":"b", "lw":5, "ls":"--", "marker":"o", "ms":15, "mec":"g", "mew":5, "mfc":"r"}
style2 = {"c":"k", "lw":3, "ls":":", "marker":"s", "ms":10, "mec":"m", "mew":5, "mfc": "c"}
plt.plot([1, 4, 9, 16], **stylel)
plt.plot([9, 16, 4, 11], **style2)
plt.show()

# %%
x = np.linspace(-np.pi, np.pi, 256)
c,s = np.cos(x), np.sin(x)
plt.title("legend를 표시한 플롯")
plt.plot(x,c, ls="--", label="cosine")
plt.plot(x,c, ls=":", label="sine")
plt.legend(loc=2) #upper left
plt.show()

# %%
x = np.linspace(-np.pi, np.pi, 256)
c,s = np.cos(x), np.sin(x)
plt.title("Cosine Plot")
plt.plot(x,c, label="cosine")
plt.xlabel('time')
plt.ylabel('amplitude')
plt.show()

# %%
x = np.arange(32,100)
plt.title('섭씨 온도와 화씨 온도')
plt.plot(x,(x-32)*5/9,'r-.')
plt.xlabel('화씨 온도')
plt.ylabel('섭씨 온도')
plt.show()

# %%
fig, ax =plt.subplots() #creating a figure containing a single axes
ax.plot([1,2,3,4],[1,4,2,3])

# %%
fig = plt.figure()

# %%
fig, ax = plt.subplots()

# %%
fig, axs = plt.subplots(2,2)

# %%
np.random.seed(0)
f1 = plt.figure(figsize=(10,2))
plt.title('figure size : (10,2)')
plt.plot(np.random.randn(100))
plt.show()

# %%
f1 = plt.figure(1)
plt.title('현재의 figure 객체')
plt.plot([1,2,3,4], 'ro:')

f2 = plt.gcf()
print(f1, id(f1))
print(f2, id(f2))
plt.show()
# Out:
# Figure(640x480) 1989301423792
# Figure(640x480) 1989301423792

# %%
asx1 = plt.subplot(2,1,1)

# %%
asx2 = plt.subplot(2,1,2)

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2*np.pi*x1)*np.exp(-x1)
y2 = np.cos(2*np.pi*x2)

ax1 = plt.subplot(2,1,1)
plt.plot(x1,y1,'yo-')
plt.title('a tale of 2 subplots')
plt.ylabel('Damped oscillation')

ax2 = plt.subplot(2,1,2)
plt.plot(x2,y2,'r.-')
plt.title('time(s)')
plt.ylabel('Undamped')

plt.tight_layout()
plt.show()

# %%
np.random.seed(0)

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title('axes 1')

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title('axes 2')

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title('axes 3')

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title('axes 4')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2,2)

np.random.seed(0)
axes[0,0].plot(np.random.rand(5))
axes[0,0].set_title('axes 1')
axes[0,1].plot(np.random.rand(5))
axes[0,1].set_title('axes 2')
axes[1,0].plot(np.random.rand(5))
axes[1,0].set_title('axes 3')
axes[1,1].plot(np.random.rand(5))
axes[1,1].set_title('axes 4')
# Out:
# Text(0.5, 1.0, 'axes 4')

# %%
fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title('x축 공유하는 y축 2개')
ax0.plot([10,5,2,9,7], 'r-', label='y0')
ax0.set_ylabel('y0')
ax0.grid(False)
ax1.plot([100,200,220,180,120], 'g:', label='y1')
ax1.set_ylabel('y1')
ax1.grid(False)
plt.show()

# %%
y = [2, 3, 1]
x = ['가', '나', '다']
plt.title("Bar Chart")
plt.bar(x, y)
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()

# %%
y = [2, 3, 1]
x = ['가', '나', '다']
colors = ['r','g','b']
plt.title("Bar Chart")
plt.bar(x, y, color=colors)
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()

# %%
np.random.seed (0)
people = ['몽룡', '춘향', '방자', '향단']
performance = 3 + 10 * np.random.rand (len (people))
error = np.random.rand (len (people))
plt.title("Barh Chart")
plt.barh (people, performance, xerr=error, alpha=0.4)
plt.xlabel('x 라벨')
plt.show()

# %%
titanic = sns.load_dataset('titanic')

# %%
a = titanic.alive.value_counts()['no']
b = titanic.alive.value_counts()['yes']

# %%
titanic = sns.load_dataset('titanic')

a = titanic.alive.value_counts()['no']
b = titanic.alive.value_counts()['yes']

status = ['사망자','생존자']
people_number = [a,b]
colors = ['r','g']

plt.title('타이타닉호 생존 여부')
plt.barh(status, people_number, color=colors)
plt.xlabel('인원 수')
plt.show()

# %%
labels = ['월세', '전세', '자가', '기타']
sizes= [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode= (-1, 3, 1, 4)
plt.title("Pie Chart")
plt.pie (sizes, explode=explode, labels=labels, colors=colors,
         autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis ('equal') #원의 형태 유지
plt.show()

# %%
bins = [0, 20, 30, 50, 70, 100]
labels = ["미성년자", "청년", "장년", "중년", "노년"]
explode = (0.1, 0, 0, 0, 0)
colors = ["yellowgreen", "gold", "lightskyblue", "lightcoral", "orange"]

# %%
titanic.age = titanic.age.dropna()

labels = ["미성년자", "청년", "장년", "중년", "노년"]
sizes= [] #승객 나이 비율
colors = ["yellowgreen", "gold", "lightskyblue", "lightcoral", "orange"]
explode= (0.1, 0, 0, 0, 0)
plt.title("타이타닉호 승객 나이 그룹")
plt.pie (sizes, explode=explode, labels=labels, colors=colors,
         autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis ('equal') #원의 형태 유지
plt.show()

# %%
titanic['age'] = titanic.age.dropna()

titanic.age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
np.random.seed(0)
x = np.random.randn(1000)
plt.title('Histogram')
arrays, bins, patches = plt.hist(x, bins=10)
plt.show()

# %%
np.random.seed (0)
X = np.random.normal(0, 1, 100)
Y = np.random.normal(0, 1, 100)
plt.title("Scatter Plot")
plt.scatter (X, Y)
plt.show()

# %%
N = 30
np.random.seed (0)
x = np.random.rand (N)
yl = np.random.rand (N)
y2 = np.random.rand (N)
y3 = np.pi* (15 * np.random.rand (N)) **2
plt.title("Bubble Chart")
plt.scatter(x, yl, c=y2, s=y3)
plt.show()

# %%
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.images [7]
X
# Out:
# array([[ 0.,  0.,  7.,  8., 13., 16., 15.,  1.],
#        [ 0.,  0.,  7.,  7.,  4., 11., 12.,  0.],
#        [ 0.,  0.,  0.,  0.,  8., 13.,  1.,  0.],
#        [ 0.,  4.,  8.,  8., 15., 15.,  6.,  0.],
#        [ 0.,  2., 11., 15., 15.,  4.,  0.,  0.],
#        [ 0.,  0.,  0., 16.,  5.,  0.,  0.,  0.],
#        [ 0.,  0.,  9., 15.,  1.,  0.,  0.,  0.],
#        [ 0.,  0., 13.,  5.,  0.,  0.,  0.,  0.]])

# %%
plt.title("mnist digits; 0")
plt.imshow(X, interpolation='nearest', cmap=plt.cm.bone_r)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.subplots_adjust(left=0.35, right=0.65, bottom=0.35, top=0.65)
plt.show()

# %%
dir(plt.cm)[:10]
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r']

# %%
fig, axes = plt.subplots (1, 4, figsize=(12, 3),
subplot_kw={'xticks': [], 'yticks': []})
axes[0].set_title("plt.cm. Blues")
axes[0].imshow (X, interpolation='nearest', cmap=plt.cm.Blues)
axes[1].set_title("plt.cm. Blues_r")
axes[1].imshow (X, interpolation='nearest', cmap=plt.cm.Blues_r)
axes[2].set_title("plt.BrBG")
axes[2].imshow (X, interpolation='nearest', cmap='BrBG')
axes[3].set_title("plt.BrBG_r")
axes[3].imshow (X, interpolation='nearest', cmap='BrBG_r')
plt.show()

# %%
methods = {
    None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36',
    'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian',
    'bessel', 'mitchell', 'sinc', 'lanczos'
}
fig, axes = plt.subplots(3, 6, figsize = (12, 6),
                         subplot_kw = {'xticks' : [], 'yticks' : []})
for ax, interp_method in zip(axes.flat, methods):
    ax.imshow(X, cmap = plt.cm.bone_r, interpolation = interp_method)
    ax.set_title(interp_method)
    
plt.show()
