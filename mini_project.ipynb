# %%
import requests
import numpy as np
import pandas as pd
import seaborn as sns

# %%
response = requests.get('http://api.kcisa.kr/openapi/service/rest/meta/CHAheri?serviceKey=%208c5cdc04-01ba-4e4b-9c80-ee6b65e562fd&numOfRows=10&pageNo=1')
print(response.status_code)
# Out:
# 403

# %%
import requests
url = 'http://api.kcisa.kr/openapi/service/rest/meta/CHAheri'
params = {'serviceKey' : '8c5cdc04-01ba-4e4b-9c80-ee6b65e562fd','numOfRows':1000,'pageNo':1}
response = requests.get(url, params)
response.status_code
response.headers
x=response.text

import xmltodict
a=xmltodict.parse(x)['response']['body']['items']['item']
l = [i['subjectKeyword'] for i in xmltodict.parse(x)['response']['body']['items']['item']]
set(l)
# Out:
# {'국보',
#  '등록문화재',
#  '문화재자료',
#  '보물',
#  '사적',
#  '시도기념물',
#  '시도무형',
#  '시도민속문화재',
#  '시도유형',
#  '중요무형문화재',
#  '중요민속문화재',
#  '천연기념물'}

# %%
op = pd.DataFrame(a)
op
# Out:
#                                                 title alternativeTitle  \
# 0                        덕수궁 중화전 및 중화문(德壽宮 中和殿 및 中和門)             None
# 1    청양 장곡사 철조비로자나불좌상 및 석조대좌(靑陽 長谷寺 鐵造毘盧遮那佛坐像 및 石造臺座)             None
# 2                       보령수부리귀부및이수(保寧水芙里龜趺및&#34733;首)             None
# 3                                  무량사김시습부도(無量寺金時習浮屠)             None
# 4                                중원김위묘출토유물(中原金緯墓出土遺物)             None
# ..                                                ...              ...
# 995                                  세전리석불입상(細田里石佛立像)             None
# 996      불국사 삼층석탑 사리장엄구 - 수정대옥(佛國寺 三層石塔 舍利莊嚴具 - 水晶大玉)             None
# 997                              보은 최동근 고가(報恩 崔東根 古家)             None
# 998                                  사천와룡동사지(泗川臥龍洞寺址)             None
# 999                              나주죽림사소장괘불(羅州竹林寺所藏掛佛)             None
#
#     creator              regDate collectionDb subjectCategory subjectKeyword  \
# 0       누리집  2021-02-23 01:48:39        문화재정보            None             보물
# 1       누리집  2021-02-23 01:48:39        문화재정보            None             보물
# 2       누리집  2021-02-23 01:48:39        문화재정보            None           시도유형
# 3       누리집  2021-02-23 01:48:39        문화재정보            None           시도유형
# 4       누리집  2021-02-23 01:48:39        문화재정보            None        중요민속문화재
# ..      ...                  ...          ...             ...            ...
# 995     누리집  2021-02-23 01:48:47        문화재정보            None           시도유형
# 996     누리집  2021-02-23 01:48:47        문화재정보            None             국보
# 997     누리집  2021-02-23 01:48:47        문화재정보            None          문화재자료
# 998     누리집  2021-02-23 01:48:47        문화재정보            None          시도기념물
# 999     누리집  2021-02-23 01:48:47        문화재정보            None           시도유형
#
#              extent                                        description  \
# 0              조선시대  중화전은 덕수궁의 중심 건물로 임금님이 하례(賀禮)를 받거나 국가 행사를 거행하던 ...
# 1              고려시대  충청남도 청양 칠갑산에 자리잡은 장곡사의 상대웅전 안에 모셔져 있는 불상으로 진리의...
# 2              None  영수암(예전의 단원사) 경내에 서 있는 비로, 근처의 절터에 있던 것을 수습하여 이...
# 3              None  매월당 김시습(1435∼1493)의 사리를 모신 부도이다.\n 김시습은 생육신의 한...
# 4            17세기 초  1980년 충주댐 건설로 인하여 충북 청원군에 있던 조선중기의 문신인 김위의 묘를 ...
# ..              ...                                                ...
# 995            None  전라북도 남원시 송동면 세전리 뒷산에서 발굴된 불상으로, 전체 높이는 2.7m이다....
# 996     통일신라시대(8세기)                                               None
# 997            None  삼승면 선곡리는 화순최씨 집성촌으로 본 가옥은 최동근 출생 이전에 건축된 가옥으로 ...
# 998            None  사천와룡동사지는 와룡산의 와룡골 안에 있는 옛 절터이다.\n 불교사에는 와룡사의 이...
# 999  조선시대 중기(1622년)                                               None
#
#                            spatial temporal person language sourceTitle  \
# 0               서울 중구 세종대로 99 (정동)     None   None      kor        None
# 1    충남 청양군 대치면 장곡길 241, 장곡사 (장곡리)     None   None      kor        None
# 2              충남 보령시 웅천읍 수부리 13번지     None   None      kor        None
# 3          충남 부여군 외산면 만수리 산125-1번지     None   None      kor        None
# 4    충북 청주시 흥덕구 개신동 산48번지 충북대학교박물관     None   None      kor        None
# ..                             ...      ...    ...      ...         ...
# 995           전북 남원시 송동면 세전리 산17번지     None   None      kor        None
# 996    우정국로 55, 불교중앙박물관 (견지동,광교빌딩)     None   None      kor        None
# 997              삼승면 선곡리 313-1번지 외     None   None      kor        None
# 998               경남 사천시 와룡동 279번지     None   None      kor        None
# 999                전남 나주시 남평읍 산1번지     None   None      kor        None
#
#     rights copyrightOthers                                 uci contributor
# 0     None            None  G706+CHAB21-B.chaCpInfo.0000000734        None
# 1     None            None  G706+CHAB21-B.chaCpInfo.0000001647        None
# 2     None            None  G706+CHAB21-B.chaCpInfo.0000006765        None
# 3     None            None  G706+CHAB21-B.chaCpInfo.0000006758        None
# 4     None            None  G706+CHAB21-B.chaCpInfo.0000004487        None
# ..     ...             ...                                 ...         ...
# 995   None            None  G706+CHAB21-B.chaCpInfo.0000007062        None
# 996   None            None  G706+CHAB21-B.chaCpInfo.0000000068        None
# 997   None            None  G706+CHAB21-B.chaCpInfo.0000012613        None
# 998   None            None  G706+CHAB21-B.chaCpInfo.0000010987        None
# 999   None            None  G706+CHAB21-B.chaCpInfo.0000007357        None
#
# [1000 rows x 18 columns]

# %%
op2 = op[op['spatial'].str.contains('서울', na=False)]
op2
# Out:
#                              title alternativeTitle creator  \
# 0     덕수궁 중화전 및 중화문(德壽宮 中和殿 및 中和門)             None     누리집
# 19        금동미륵보살반가사유상(金銅彌勒菩薩半跏思惟像)             None     누리집
# 29      윤순거 초서 무이구곡가(尹舜擧 草書 武夷九曲歌)             None     누리집
# 31                      경희궁지(慶熙宮址)             None     누리집
# 34      서울 중앙고등학교 본관(서울 中央高等學校 本館)             None     누리집
# ..                             ...              ...     ...
# 939           장교동한규설가옥(長橋洞 韓圭卨 家屋)             None     누리집
# 950         묘법연화경 권6~7(妙法蓮華經 卷6~7)             None     누리집
# 965                   고대 그리스 청동 투구             None     누리집
# 968  상교정본자비도량참법 권10(詳校正本慈悲道場懺法 卷十)             None     누리집
# 990         청자 표주박모양 주전자(靑磁 瓢形 注子)             None     누리집
#
#                  regDate collectionDb subjectCategory subjectKeyword  \
# 0    2021-02-23 01:48:39        문화재정보            None             보물
# 19   2021-02-23 01:48:39        문화재정보            None             국보
# 29   2021-02-23 01:48:39        문화재정보            None             보물
# 31   2021-02-23 01:48:39        문화재정보            None             사적
# 34   2021-02-23 01:48:39        문화재정보            None             사적
# ..                   ...          ...             ...            ...
# 939  2021-02-23 01:48:46        문화재정보            None        시도민속문화재
# 950  2021-02-23 01:48:46        문화재정보            None             보물
# 965  2021-02-23 01:48:46        문화재정보            None             보물
# 968  2021-02-23 01:48:46        문화재정보            None             보물
# 990  2021-02-23 01:48:46        문화재정보            None             보물
#
#               extent                                        description  \
# 0               조선시대  중화전은 덕수궁의 중심 건물로 임금님이 하례(賀禮)를 받거나 국가 행사를 거행하던 ...
# 19              삼국시대  의자 위에 앉아 오른발을 왼쪽다리 위에 올려 놓고, 오른쪽 팔꿈치를 무릎 위에 올린...
# 29           17세기 후반  윤순거 초서 무이구곡가는 동토(童土) 윤순거(尹舜擧, 1596～1668)의 대표작으...
# 31   조선 광해군 8년(1616)  원종의 집터에 세워진 조선후기의 대표적인 이궁이다.\n 원종(1580∼1619)은 ...
# 34             1937년  일제시대에 박동진이 설계하여 지은 석조 2층 건물이다.\n 1917년 중학 과정으로...
# ..               ...                                                ...
# 939             None  조선 후기 한성판윤을 지낸 한규설(1848∼1930)의 저택이다. 원래 장교동에 있...
# 950             None  묘법연화경은 줄여서 ‘법화경’이라고 부르기도 하며, 부처가 되는 길이 누구에게나 열...
# 965             None  1936년 손기정이 베를린 올림픽 경기대회 마라톤 경기에서 우승한 기념으로 받은 높...
# 968             None  자비도량참법은 경전을 읽으면서 죄를 참회하는 불교의식을 말하며, 이를 수행하면 죄가...
# 990             12세기  고려시대(12세기)의 조형적 특징을 보이는 표주박 형태의 청자 주자(注子)이다. 표...
#
#                                     spatial temporal person language  \
# 0                        서울 중구 세종대로 99 (정동)     None   None      kor
# 19   서울 용산구 서빙고로 137, 국립중앙박물관 (용산동5가,임향한의원)     None   None      kor
# 29   서울 용산구 서빙고로 137, 국립중앙박물관 (용산동5가,임향한의원)     None   None      kor
# 31                   서울 종로구 새문안로 45 (신문로2가)     None   None      kor
# 34                     서울 종로구 창덕궁길 164 (계동)     None   None      kor
# ..                                      ...      ...    ...      ...
# 939               서울 성북구 정릉3동 855-2번지 국민대학교     None   None      kor
# 950            서울 서초구 바우뫼로7길 111, 관문사 (우면동)     None   None      kor
# 965  서울 용산구 서빙고로 137, 국립중앙박물관 (용산동5가,임향한의원)     None   None      kor
# 968    서울 용산구 이태원로55길 60-16, 삼성미술관 리움 (한남동)     None   None      kor
# 990  서울 관악구 남부순환로152길 53, 호림박물관 (신림동,호림박물관)     None   None      kor
#
#     sourceTitle rights copyrightOthers                                 uci  \
# 0          None   None            None  G706+CHAB21-B.chaCpInfo.0000000734
# 19         None   None            None  G706+CHAB21-B.chaCpInfo.0000000014
# 29         None   None            None  G706+CHAB21-B.chaCpInfo.0000001086
# 31         None   None            None  G706+CHAB21-B.chaCpInfo.0000002918
# 34         None   None            None  G706+CHAB21-B.chaCpInfo.0000002925
# ..          ...    ...             ...                                 ...
# 939        None   None            None  G706+CHAB21-B.chaCpInfo.0000011269
# 950        None   None            None  G706+CHAB21-B.chaCpInfo.0000000810
# 965        None   None            None  G706+CHAB21-B.chaCpInfo.0000000790
# 968        None   None            None  G706+CHAB21-B.chaCpInfo.0000000802
# 990        None   None            None  G706+CHAB21-B.chaCpInfo.0000001050
#
#     contributor
# 0          None
# 19         None
# 29         None
# 31         None
# 34         None
# ..          ...
# 939        None
# 950        None
# 965        None
# 968        None
# 990        None
#
# [137 rows x 18 columns]

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.14.0-py2.py3-none-any.whl (102 kB)
#      ---------------------------------------- 102.3/102.3 kB ? eta 0:00:00
# Collecting branca>=0.6.0
#   Downloading branca-0.6.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\user\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->folium) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->folium) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->folium) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Installing collected packages: branca, folium
# Successfully installed branca-0.6.0 folium-0.14.0

# %%
import folium

# %%
latitude = berlin_week.lat[0]
longitude = berlin_week.lng[0]
m = folium.Map(location=[latitude, longitude],
               zoom_start=17, 
               width=750, 
               height=500
              )
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b33654e7fa247a9da7b2ba4da7bca717 {
#                     position: relative;
#                     width: 750.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b33654e7fa247a9da7b2ba4da7bca717&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b33654e7fa247a9da7b2ba4da7bca717 = L.map(
#                 &quot;map_b33654e7fa247a9da7b2ba4da7bca717&quot;,
#                 {
#                     center: [52.4915, 13.42344],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ae12c7301308a2fd471cd0fcbbdd7ef3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b33654e7fa247a9da7b2ba4da7bca717);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker([latitude, longitude],
              popup="베를린 숙소",
              tooltip="베를린 숙소").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b33654e7fa247a9da7b2ba4da7bca717 {
#                     position: relative;
#                     width: 750.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b33654e7fa247a9da7b2ba4da7bca717&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b33654e7fa247a9da7b2ba4da7bca717 = L.map(
#                 &quot;map_b33654e7fa247a9da7b2ba4da7bca717&quot;,
#                 {
#                     center: [52.4915, 13.42344],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ae12c7301308a2fd471cd0fcbbdd7ef3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b33654e7fa247a9da7b2ba4da7bca717);
#
#
#             var marker_2227eba09bc85e866a2d8c304c76c895 = L.marker(
#                 [52.4915, 13.42344],
#                 {}
#             ).addTo(map_b33654e7fa247a9da7b2ba4da7bca717);
#
#
#         var popup_d2f63f0d3ad71f3ba412efae70740af3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_975c19b1ee83b510082e9f164e2e3f12 = $(`&lt;div id=&quot;html_975c19b1ee83b510082e9f164e2e3f12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;베를린 숙소&lt;/div&gt;`)[0];
#                 popup_d2f63f0d3ad71f3ba412efae70740af3.setContent(html_975c19b1ee83b510082e9f164e2e3f12);
#
#
#
#         marker_2227eba09bc85e866a2d8c304c76c895.bindPopup(popup_d2f63f0d3ad71f3ba412efae70740af3)
#         ;
#
#
#
#
#             marker_2227eba09bc85e866a2d8c304c76c895.bindTooltip(
#                 `&lt;div&gt;
#                      베를린 숙소
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
