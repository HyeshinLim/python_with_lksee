# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
np.random.seed(0)
df1 = pd.DataFrame(np.vstack([list('ABCDE'),
                             np.round(np.random.rand(3,5),2)]).T,
                   columns=['C1','C2','C3','C4'])
df1
# Out:
#   C1    C2    C3    C4
# 0  A  0.55  0.65  0.79
# 1  B  0.72  0.44  0.53
# 2  C   0.6  0.89  0.57
# 3  D  0.54  0.96  0.93
# 4  E  0.42  0.38  0.07

# %%
df2=df1.set_index('C1')
df2
# Out:
#       C2    C3    C4
# C1
# A   0.55  0.65  0.79
# B   0.72  0.44  0.53
# C    0.6  0.89  0.57
# D   0.54  0.96  0.93
# E   0.42  0.38  0.07

# %%
df2.set_index('C2')
# Out:
#         C3    C4
# C2
# 0.55  0.65  0.79
# 0.72  0.44  0.53
# 0.6   0.89  0.57
# 0.54  0.96  0.93
# 0.42  0.38  0.07

# %%
nfl = pd.read_csv('datas/nfl.csv', parse_dates=['Birthday'], index_col=['Name'])
nfl
# Out:
#                                     Team Position   Birthday   Salary
# Name
# Tremon Smith         Philadelphia Eagles       RB 1996-07-20   570000
# Shawn Williams        Cincinnati Bengals       SS 1991-05-13  3500000
# Adam Butler         New England Patriots       DT 1994-04-12   645000
# Derek Wolfe               Denver Broncos       DE 1990-02-24  8000000
# Jake Ryan           Jacksonville Jaguars      OLB 1992-02-27  1000000
# ...                                  ...      ...        ...      ...
# Bashaud Breeland      Kansas City Chiefs       CB 1992-01-30   805000
# Craig James          Philadelphia Eagles       CB 1996-04-29   570000
# Jonotthan Harrison         New York Jets        C 1991-08-25  1500000
# Chuma Edoga                New York Jets       OT 1997-05-25   495000
# Tajae Sharpe            Tennessee Titans       WR 1994-12-23  2025000
#
# [1655 rows x 4 columns]

# %%
nfl2 = nfl.reset_index('Name')

# %%
nfl3 = nfl2.set_index('Team')
nfl3.loc['New York Jets'].Birthday.sort_values(ascending=True)
# Out:
# Team
# New York Jets   1985-03-29
# New York Jets   1986-01-03
# New York Jets   1986-06-04
# New York Jets   1987-10-25
# New York Jets   1988-10-04
# New York Jets   1988-11-25
# New York Jets   1989-05-10
# New York Jets   1989-05-18
# New York Jets   1989-06-08
# New York Jets   1990-01-01
# New York Jets   1990-05-01
# New York Jets   1990-10-04
# New York Jets   1990-11-26
# New York Jets   1991-03-11
# New York Jets   1991-07-02
# New York Jets   1991-07-06
# New York Jets   1991-07-10
# New York Jets   1991-08-03
# New York Jets   1991-08-25
# New York Jets   1991-09-16
# New York Jets   1992-02-06
# New York Jets   1992-02-18
# New York Jets   1992-04-21
# New York Jets   1992-05-26
# New York Jets   1992-07-15
# New York Jets   1992-09-24
# New York Jets   1992-10-19
# New York Jets   1992-10-20
# New York Jets   1992-12-14
# New York Jets   1993-01-22
# New York Jets   1993-04-06
# New York Jets   1993-05-09
# New York Jets   1993-06-17
# New York Jets   1993-07-13
# ...

# %%
# 기본 DataFrame
data = {'이름':['일식','이식','삼식','사식','오식'],
       '국어':[60,70,90,80,100],
       '영어':[70,86,82,88,100],
       '수학':[65,82,85,90,100]}
columns = ['이름','국어','영어','수학']
df = pd.DataFrame(data, columns=columns)

# %%
# '이름'column을 인덱스로 만들었다가 원상복구 
df.set_index('이름').reset_index()
# Out:
#    이름   국어   영어   수학
# 0  일식   60   70   65
# 1  이식   70   86   82
# 2  삼식   90   82   85
# 3  사식   80   88   90
# 4  오식  100  100  100

# %%
df.reset_index().reset_index()
# Out:
#    level_0  index  이름   국어   영어   수학
# 0        0      0  일식   60   70   65
# 1        1      1  이식   70   86   82
# 2        2      2  삼식   90   82   85
# 3        3      3  사식   80   88   90
# 4        4      4  오식  100  100  100

# %%
employees = pd.read_csv('datas/employees.csv', parse_dates=['Start Date'])

# %%
#값 전부가 nan일 때 삭제 
employees.dropna(how='all')
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 0      Douglas    Male 1993-08-06       NaN   True     Marketing
# 1       Thomas    Male 1996-03-31   61933.0   True           NaN
# 2        Maria  Female        NaT  130590.0  False       Finance
# 3        Jerry     NaN 2005-03-04  138705.0   True       Finance
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# ..         ...     ...        ...       ...    ...           ...
# 995      Henry     NaN 2014-11-23  132483.0  False  Distribution
# 996    Phillip    Male 1984-01-31   42392.0  False       Finance
# 997    Russell    Male 2013-05-20   96914.0  False       Product
# 998      Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999     Albert    Male 2012-05-15  129949.0   True         Sales
#
# [1000 rows x 6 columns]

# %%
# 값 하나라도 nan이 있다면 지워라
employees.dropna(how='any')
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# 5       Dennis    Male 1987-04-18  115163.0  False         Legal
# 6         Ruby  Female 1987-08-17   65476.0   True       Product
# 8       Angela  Female 2005-11-22   95570.0   True   Engineering
# 9      Frances  Female 2002-08-08  139852.0   True  Business Dev
# ..         ...     ...        ...       ...    ...           ...
# 994     George    Male 2013-06-21   98874.0   True     Marketing
# 996    Phillip    Male 1984-01-31   42392.0  False       Finance
# 997    Russell    Male 2013-05-20   96914.0  False       Product
# 998      Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999     Albert    Male 2012-05-15  129949.0   True         Sales
#
# [761 rows x 6 columns]

# %%
# 먼저 dataframe의 값 조회
employees.loc[employees.Gender.isnull()]
# Out:
#      First Name Gender Start Date    Salary   Mgmt          Team
# 3         Jerry    NaN 2005-03-04  138705.0   True       Finance
# 20         Lois    NaN 1995-04-22   64714.0   True         Legal
# 22       Joshua    NaN 2012-03-08   90816.0   True            IT
# 27        Scott    NaN 1991-07-11  122367.0  False         Legal
# 31        Joyce    NaN 2005-02-20   88657.0  False       Product
# ...         ...    ...        ...       ...    ...           ...
# 972      Victor    NaN 2006-07-28   76381.0   True         Sales
# 985     Stephen    NaN 1983-07-10   85668.0  False         Legal
# 989      Justin    NaN 1991-02-10   38344.0  False         Legal
# 995       Henry    NaN 2014-11-23  132483.0  False  Distribution
# 1000        NaN    NaN        NaT       NaN    NaN           NaN
#
# [147 rows x 6 columns]

# %%
# employees df에서 Gender column에 있는 nan값이 있는 것들만 삭제
employees.dropna(subset='Gender')
# Out:
#     First Name  Gender Start Date    Salary   Mgmt          Team
# 0      Douglas    Male 1993-08-06       NaN   True     Marketing
# 1       Thomas    Male 1996-03-31   61933.0   True           NaN
# 2        Maria  Female        NaT  130590.0  False       Finance
# 4        Larry    Male 1998-01-24  101004.0   True            IT
# 5       Dennis    Male 1987-04-18  115163.0  False         Legal
# ..         ...     ...        ...       ...    ...           ...
# 994     George    Male 2013-06-21   98874.0   True     Marketing
# 996    Phillip    Male 1984-01-31   42392.0  False       Finance
# 997    Russell    Male 2013-05-20   96914.0  False       Product
# 998      Larry    Male 2013-04-20   60500.0  False  Business Dev
# 999     Albert    Male 2012-05-15  129949.0   True         Sales
#
# [854 rows x 6 columns]

# %%
con1 = employees['Start Date'].isnull()
con2 = employees['Salary'].isnull()
print(f'con1: {con1.sum()}, con2: {con2.sum()}')
# Out:
# con1: 2, con2: 2

# %%
employees[con1]
# Out:
#      First Name  Gender Start Date    Salary   Mgmt     Team
# 2         Maria  Female        NaT  130590.0  False  Finance
# 1000        NaN     NaN        NaT       NaN    NaN      NaN

# %%
employees[con2]
# Out:
#      First Name Gender Start Date  Salary  Mgmt       Team
# 0       Douglas   Male 1993-08-06     NaN  True  Marketing
# 1000        NaN    NaN        NaT     NaN   NaN        NaN

# %%
# 중복은 제외하고 원하는 값들을 모아서 보여줌
employees[con1|con2]
# Out:
#      First Name  Gender Start Date    Salary   Mgmt       Team
# 0       Douglas    Male 1993-08-06       NaN   True  Marketing
# 2         Maria  Female        NaT  130590.0  False    Finance
# 1000        NaN     NaN        NaT       NaN    NaN        NaN

# %%
inspections = pd.read_csv('datas/chicago_food_inspections.csv')
inspections['Name'].head().values
# Out:
# array([' MARRIOT MARQUIS CHICAGO   ', ' JETS PIZZA ', '   ROOM 1520 ',
#        '  MARRIOT MARQUIS CHICAGO  ', ' CHARTWELLS   '], dtype=object)

# %%
inspections['Name'].str

# %%
inspections['Name'] = inspections['Name'].str.strip()

# %%
# inspections에 있는 column의 모든 문자 공백을 없애고 싶을 때
for column in inspections.columns:
    inspections[column]=inspections[column].str.strip()

# %%
inspections = inspections.dropna(subset=['Risk'])

# %%
inspections = inspections.replace(
    to_replace='All', value='Risk 4 (Extreme)')

# %%
inspections['Risk'].unique()
# Out:
# array(['Risk 1 (High)', 'Risk 2 (Medium)', 'Risk 3 (Low)',
#        'Risk 4 (Extreme)'], dtype=object)

# %%
# 문자열 인덱싱
inspections['Risk'].str[5].astype('i').head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    1
# 4    1
# Name: Risk, dtype: int32

# %%
# 문자열 인덱싱
inspections['Risk'].str[3].head()
# Out:
# 0    k
# 1    k
# 2    k
# 3    k
# 4    k
# Name: Risk, dtype: object

# %%
# 문자열 슬라이싱

# Risk 1 (High)
# 012345678   <- 인덱스
# 'Risk 1 (High)'의 인덱스 8은 H
inspections['Risk'].str[8:-1].astype('category').head()
# Out:
# 0      High
# 1    Medium
# 2       Low
# 3      High
# 4      High
# Name: Risk, dtype: category
# Categories (4, object): ['Extreme', 'High', 'Low', 'Medium']

# %%
#다중 인덱스
np.random.seed(0)
df3 = pd.DataFrame(np.round(np.random.randn(5,4),2),
                  columns=[['A','A','B','B'],
                          ['C1','C2','C1','C2']])
df3
# Out:
#       A           B
#      C1    C2    C1    C2
# 0  1.76  0.40  0.98  2.24
# 1  1.87 -0.98  0.95 -0.15
# 2 -0.10  0.41  0.14  1.45
# 3  0.76  0.12  0.44  0.33
# 4  1.49 -0.21  0.31 -0.85

# %%
#다중 인덱스
np.random.seed(0)
df3 = pd.DataFrame(np.round(np.random.randn(5,4),2),
                  columns=[['A','A','B','B'],
                          ['C1','C2','C1','C2']])
df3
# Out:
#       A           B
#      C1    C2    C1    C2
# 0  1.76  0.40  0.98  2.24
# 1  1.87 -0.98  0.95 -0.15
# 2 -0.10  0.41  0.14  1.45
# 3  0.76  0.12  0.44  0.33
# 4  1.49 -0.21  0.31 -0.85

# %%
df3.columns.names = ['Cidx1','Cidx2']
df3
# Out:
# Cidx1     A           B
# Cidx2    C1    C2    C1    C2
# 0      1.76  0.40  0.98  2.24
# 1      1.87 -0.98  0.95 -0.15
# 2     -0.10  0.41  0.14  1.45
# 3      0.76  0.12  0.44  0.33
# 4      1.49 -0.21  0.31 -0.85

# %%
dfStyler = df3.style.set_properties(**{'text-align': 'left'})
dfStyler.set_table_styles([dict(selector='th',
                                props=[('text-align', 'left')])])
# Out:
# <style type="text/css">
# #T_73006 th {
#   text-align: left;
# }
# #T_73006_row0_col0, #T_73006_row0_col1, #T_73006_row0_col2, #T_73006_row0_col3, #T_73006_row1_col0, #T_73006_row1_col1, #T_73006_row1_col2, #T_73006_row1_col3, #T_73006_row2_col0, #T_73006_row2_col1, #T_73006_row2_col2, #T_73006_row2_col3, #T_73006_row3_col0, #T_73006_row3_col1, #T_73006_row3_col2, #T_73006_row3_col3, #T_73006_row4_col0, #T_73006_row4_col1, #T_73006_row4_col2, #T_73006_row4_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_73006">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Cidx1</th>
#       <th id="T_73006_level0_col0" class="col_heading level0 col0" colspan="2">A</th>
#       <th id="T_73006_level0_col2" class="col_heading level0 col2" colspan="2">B</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Cidx2</th>
#       <th id="T_73006_level1_col0" class="col_heading level1 col0" >C1</th>
# ...

# %%
#다중 인덱스
np.random.seed(0)
df4 = pd.DataFrame(np.round(np.random.randn(6,4),2),
                  columns = [['A','A','B','B'],
                          ['C','D','C','D']],
                  index = [['M','M','M','F','F','F'],
                           ['id_'+str(i+1) for i in range(3)]*2])
df4.columns.names = ['Cidx1','Cidx2']
df4.index.names = ['Ridx1','Ridx2']
df4
# Out:
# Cidx1           A           B
# Cidx2           C     D     C     D
# Ridx1 Ridx2
# M     id_1   1.76  0.40  0.98  2.24
#       id_2   1.87 -0.98  0.95 -0.15
#       id_3  -0.10  0.41  0.14  1.45
# F     id_1   0.76  0.12  0.44  0.33
#       id_2   1.49 -0.21  0.31 -0.85
#       id_3  -2.55  0.65  0.86 -0.74

# %%
# column인덱스가 반시계 방향으로 
df4.stack('Cidx1')
# Out:
# Cidx2                 C     D
# Ridx1 Ridx2 Cidx1
# M     id_1  A      1.76  0.40
#             B      0.98  2.24
#       id_2  A      1.87 -0.98
#             B      0.95 -0.15
#       id_3  A     -0.10  0.41
#             B      0.14  1.45
# F     id_1  A      0.76  0.12
#             B      0.44  0.33
#       id_2  A      1.49 -0.21
#             B      0.31 -0.85
#       id_3  A     -2.55  0.65
#             B      0.86 -0.74

# %%
# row 인덱스가 시계 방향으로 90도
df4.unstack('Ridx1')
# Out:
# Cidx1     A                       B
# Cidx2     C           D           C           D
# Ridx1     F     M     F     M     F     M     F     M
# Ridx2
# id_1   0.76  1.76  0.12  0.40  0.44  0.98  0.33  2.24
# id_2   1.49  1.87 -0.21 -0.98  0.31  0.95 -0.85 -0.15
# id_3  -2.55 -0.10  0.65  0.41  0.86  0.14 -0.74  1.45

# %%
df4.stack('Cidx1')
# Out:
# Cidx2                 C     D
# Ridx1 Ridx2 Cidx1
# M     id_1  A      1.76  0.40
#             B      0.98  2.24
#       id_2  A      1.87 -0.98
#             B      0.95 -0.15
#       id_3  A     -0.10  0.41
#             B      0.14  1.45
# F     id_1  A      0.76  0.12
#             B      0.44  0.33
#       id_2  A      1.49 -0.21
#             B      0.31 -0.85
#       id_3  A     -2.55  0.65
#             B      0.86 -0.74

# %%
df4.stack(0)
# Out:
# Cidx2                 C     D
# Ridx1 Ridx2 Cidx1
# M     id_1  A      1.76  0.40
#             B      0.98  2.24
#       id_2  A      1.87 -0.98
#             B      0.95 -0.15
#       id_3  A     -0.10  0.41
#             B      0.14  1.45
# F     id_1  A      0.76  0.12
#             B      0.44  0.33
#       id_2  A      1.49 -0.21
#             B      0.31 -0.85
#       id_3  A     -2.55  0.65
#             B      0.86 -0.74

# %%
# 인덱스가 2개니까
df3[('B','C1')]
# Out:
# 0    0.98
# 1    0.95
# 2    0.14
# 3    0.44
# 4    0.31
# Name: (B, C1), dtype: float64

# %%
df3
# Out:
# Cidx1     A           B
# Cidx2    C1    C2    C1    C2
# 0      1.76  0.40  0.98  2.24
# 1      1.87 -0.98  0.95 -0.15
# 2     -0.10  0.41  0.14  1.45
# 3      0.76  0.12  0.44  0.33
# 4      1.49 -0.21  0.31 -0.85

# %%
df3.loc[0,('B','C1')]
# Out:
# 0.98

# %%
df3.loc[0,('B','C1')]=100

# %%
df3
# Out:
# Cidx1     A             B
# Cidx2    C1    C2      C1    C2
# 0      1.76  0.40  100.00  2.24
# 1      1.87 -0.98    0.95 -0.15
# 2     -0.10  0.41    0.14  1.45
# 3      0.76  0.12    0.44  0.33
# 4      1.49 -0.21    0.31 -0.85

# %%
# iloc은 위에 어떻게 생겼든 상관 없음
df3.iloc[0,3]
# Out:
# 2.24

# %%
# 하나만 입력하면 상위 값 출력
df3['A']
# Out:
# Cidx2    C1    C2
# 0      1.76  0.40
# 1      1.87 -0.98
# 2     -0.10  0.41
# 3      0.76  0.12
# 4      1.49 -0.21

# %%
df4.loc[:,('A','C')]
# Out:
# Ridx1  Ridx2
# M      id_1     1.76
#        id_2     1.87
#        id_3    -0.10
# F      id_1     0.76
#        id_2     1.49
#        id_3    -2.55
# Name: (A, C), dtype: float64

# %%
df4.loc[('M','id_1'),:]
# Out:
# Cidx1  Cidx2
# A      C        1.76
#        D        0.40
# B      C        0.98
#        D        2.24
# Name: (M, id_1), dtype: float64

# %%
df4.loc[('All','All'),:] = df4.sum()
df4
# Out:
# Cidx1           A           B
# Cidx2           C     D     C     D
# Ridx1 Ridx2
# M     id_1   1.76  0.40  0.98  2.24
#       id_2   1.87 -0.98  0.95 -0.15
#       id_3  -0.10  0.41  0.14  1.45
# F     id_1   0.76  0.12  0.44  0.33
#       id_2   1.49 -0.21  0.31 -0.85
#       id_3  -2.55  0.65  0.86 -0.74
# All   All    3.23  0.39  3.68  2.28

# %%
# slice(None)은 [:]는 같은 의미로 전체 범위를 뜻한다

# %%
# ()안에는 변경할 애들, axis를 씀

df6 = df4.swaplevel('Cidx1','Cidx2',1)
df6
# Out:
# Cidx2           C     D     C     D
# Cidx1           A     A     B     B
# Ridx1 Ridx2
# M     id_1   1.76  0.40  0.98  2.24
#       id_2   1.87 -0.98  0.95 -0.15
#       id_3  -0.10  0.41  0.14  1.45
# F     id_1   0.76  0.12  0.44  0.33
#       id_2   1.49 -0.21  0.31 -0.85
#       id_3  -2.55  0.65  0.86 -0.74
# All   All    3.23  0.39  3.68  2.28

# %%
df1 = pd.DataFrame({
    '고객번호': [1001, 1002, 1003, 1004, 1005, 1006, 1007],
    '이름':['둘리', '도우너', '또치', '길동', '희동', '마이콜', '영희']
}, columns=['고객번호', '이름'])
df1
# Out:
#    고객번호   이름
# 0  1001   둘리
# 1  1002  도우너
# 2  1003   또치
# 3  1004   길동
# 4  1005   희동
# 5  1006  마이콜
# 6  1007   영희

# %%
df2 = pd.DataFrame({
    '고객번호': [1001, 1001, 1005, 1006, 1008, 1001],
    '금액':[10000,20000,15000,5000,100000,30000]
}, columns=['고객번호', '금액'])
df2
# Out:
#    고객번호      금액
# 0  1001   10000
# 1  1001   20000
# 2  1005   15000
# 3  1006    5000
# 4  1008  100000
# 5  1001   30000

# %%
# inner join방식이 default이다. 서로 겹치는 값만 합쳐 오는 것
pd.merge(df1,df2)
# Out:
#    고객번호   이름     금액
# 0  1001   둘리  10000
# 1  1001   둘리  20000
# 2  1001   둘리  30000
# 3  1005   희동  15000
# 4  1006  마이콜   5000

# %%
# 키 값이 한 쪽에만 있어도 데이터를 보여줌
pd.merge(df1,df2, how='outer')
# Out:
#    고객번호   이름        금액
# 0  1001   둘리   10000.0
# 1  1001   둘리   20000.0
# 2  1001   둘리   30000.0
# 3  1002  도우너       NaN
# 4  1003   또치       NaN
# 5  1004   길동       NaN
# 6  1005   희동   15000.0
# 7  1006  마이콜    5000.0
# 8  1007   영희       NaN
# 9  1008  NaN  100000.0

# %%
np.random.seed (0)
df2= pd.DataFrame({
    'key1': [ 'A', 'A', 'B', 'B', 'A'],
    'key2': [ 'one', 'two', 'one', 'two', 'one'],
    'data1': [1, 2, 3, 4, 5],
    'data2': [10, 20, 30, 40, 50]
             })
df2
# Out:
#   key1 key2  data1  data2
# 0    A  one      1     10
# 1    A  two      2     20
# 2    B  one      3     30
# 3    B  two      4     40
# 4    A  one      5     50

# %%
groups = df2.groupby(df2.key1)
groups.sum()
# Out:
#       data1  data2
# key1
# A         8     80
# B         7     70

# %%
df2.data1.groupby(df2.key1).sum()
# Out:
# key1
# A    8
# B    7
# Name: data1, dtype: int64

# %%
df2
# Out:
#   key1 key2  data1  data2
# 0    A  one      1     10
# 1    A  two      2     20
# 2    B  one      3     30
# 3    B  two      4     40
# 4    A  one      5     50

# %%
date_str = ["2018, 1, 1", "2018, 1, 4", "2018, 1, 5", "2018, 1, 6"]
idx = pd.to_datetime(date_str)
idx
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-04', '2018-01-05', '2018-01-06'], dtype='datetime64[ns]', freq=None)

# %%
np.random.seed(0)
s=pd.Series(np.random.randn(4), index=idx)
s
# Out:
# 2018-01-01    1.764052
# 2018-01-04    0.400157
# 2018-01-05    0.978738
# 2018-01-06    2.240893
# dtype: float64

# %%
pd.date_range('2023-03-13','2023-03-21', freq='B')
# Out:
# DatetimeIndex(['2023-03-13', '2023-03-14', '2023-03-15', '2023-03-16',
#                '2023-03-17', '2023-03-20', '2023-03-21'],
#               dtype='datetime64[ns]', freq='B')

# %%
pd.date_range(start='2023-03-10', periods=30)
# Out:
# DatetimeIndex(['2023-03-10', '2023-03-11', '2023-03-12', '2023-03-13',
#                '2023-03-14', '2023-03-15', '2023-03-16', '2023-03-17',
#                '2023-03-18', '2023-03-19', '2023-03-20', '2023-03-21',
#                '2023-03-22', '2023-03-23', '2023-03-24', '2023-03-25',
#                '2023-03-26', '2023-03-27', '2023-03-28', '2023-03-29',
#                '2023-03-30', '2023-03-31', '2023-04-01', '2023-04-02',
#                '2023-04-03', '2023-04-04', '2023-04-05', '2023-04-06',
#                '2023-04-07', '2023-04-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
s = pd.Series(pd.date_range("2020-12-25", periods=100, freq="D"))
s
# Out:
# 0    2020-12-25
# 1    2020-12-26
# 2    2020-12-27
# 3    2020-12-28
# 4    2020-12-29
#         ...
# 95   2021-03-30
# 96   2021-03-31
# 97   2021-04-01
# 98   2021-04-02
# 99   2021-04-03
# Length: 100, dtype: datetime64[ns]

# %%
# https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
# Python - datetime — Basic date and time types

s.dt.strftime('%Y년 %m월 %d일')
# Out:
# 0     2020년 12월 25일
# 1     2020년 12월 26일
# 2     2020년 12월 27일
# 3     2020년 12월 28일
# 4     2020년 12월 29일
#           ...
# 95    2021년 03월 30일
# 96    2021년 03월 31일
# 97    2021년 04월 01일
# 98    2021년 04월 02일
# 99    2021년 04월 03일
# Length: 100, dtype: object

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['alive']=titanic.apply(lambda x: True if x"alive"]=='yes' else False, axis=1)
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town  alive  alone
# ...
