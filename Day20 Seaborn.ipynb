# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
font_dir = ['./fonts']
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname=font).get_name())
    mpl.font_manager.fontManager.addfont(font)
# Out:
# Noto Sans KR
# Noto Sans KR
# NanumMyeongjo
# Noto Sans KR
# Noto Sans KR
# Noto Serif KR
# Black Han Sans
# NanumMyeongjo
# NanumGothic
# NanumGothic
# Noto Sans KR
# NanumGothic
# Noto Serif KR
# Noto Serif KR
# Noto Serif KR
# Noto Serif KR
# Noto Sans KR
# Noto Sans KR
# Noto Sans KR
# Noto Serif KR
# Noto Sans KR
# Noto Sans KR
# NanumMyeongjo
# Noto Sans KR
# Noto Serif KR
# Noto Sans KR

# %%
mpl.rc('axes', unicode_minus=False)

# %%
sns.set_theme(style='darkgrid')

# %%
df = sns.load_dataset('titanic')
sns.countplot(x=df['class'])
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.countplot(data=df, x='class', hue='alive')
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.countplot(data=df, y='deck', hue='alive')
# Out:
# <AxesSubplot:xlabel='count', ylabel='deck'>

# %%
tips
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2268\3801773898.py in <module>
# ----> 1 tips
#
# NameError: name 'tips' is not defined

# %%
tips = sns.load_dataset('tips')

# %%
sns.kdeplot(data=tips, x='total_bill')
sns.rugplot(data=tips, x='total_bill')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip')
sns.rugplot(data=tips, x='total_bill', y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='time')
sns.rugplot(data=tips, x='total_bill', y='tip', hue='time')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='time')
sns.rugplot(data=tips, x='total_bill', y='tip', hue='time', height=.1)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
diamonds = sns.load_dataset('diamonds')
sns.scatterplot(data=diamonds, x='carat', y='price', s=3)
sns.rugplot(data=diamonds, x='carat', y='price', lw=1, alpha=0.005)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
penguins = sns.load_dataset('penguins')
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.histplot(data=penguins, x='flipper_length_mm')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins,y='flipper_length_mm')
# Out:
# <AxesSubplot:xlabel='Count', ylabel='flipper_length_mm'>

# %%
sns.histplot(data=penguins, x='flipper_length_mm', binwidth=3)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, x='flipper_length_mm', bins=30)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, x='flipper_length_mm', kde=True)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, x='flipper_length_mm', hue='species')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, x='flipper_length_mm', hue='species', multiple='stack')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, x='flipper_length_mm', hue='species', element='step')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, x='flipper_length_mm', hue='species', element='poly')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, x='bill_depth_mm', y='body_mass_g', hue='species')
# Out:
# <AxesSubplot:xlabel='bill_depth_mm', ylabel='body_mass_g'>

# %%
sns.histplot(penguins, x='bill_depth_mm', y='body_mass_g', hue='species', legend=False)
# Out:
# <AxesSubplot:xlabel='bill_depth_mm', ylabel='body_mass_g'>

# %%
sns.displot(penguins, x='flipper_length_mm')

# %%
sns.displot(penguins, x='flipper_length_mm', kind='kde')

# %%
sns.displot(penguins, x='flipper_length_mm', kind='ecdf')

# %%
sns.displot(penguins, x='flipper_length_mm', kde=True)

# %%
sns.displot(penguins, x='flipper_length_mm', kde=True)

# %%
sns.displot(penguins, x='flipper_length_mm', y='bill_length_mm', hue='species')

# %%
sns.displot(penguins, x='flipper_length_mm', y='bill_length_mm', kind='kde', rug=True)

# %%
sns.displot(penguins, x='flipper_length_mm', kind='kde', hue='species')

# %%
sns.displot(penguins, x='flipper_length_mm', hue='species', col='sex', kind='kde')

# %%
sns.displot(
    penguins, y='flipper_length_mm', hue='sex', col='species', kind='ecdf', height=4, aspect=.7)

# %%
sns.displot(
    penguins, y='flipper_length_mm', hue='sex', row='species', kind='ecdf', height=4, aspect=.7)

# %%
g=sns.displot(data=penguins, y="flipper_length_mm", hue="sex", col="species",kind="kde", height=4, aspect=.7,)
g.set_axis_labels ("Density (a.u.)", "Flipper length (mm)")
g.set_titles ("{col_name} penguins")

# %%
df = sns.load_dataset('penguins')
sns.barplot(data=df, x='species',y='body_mass_g',hue='sex')
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
df = sns.load_dataset('titanic')
sns.boxplot(x=df['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.boxplot(data=df, x='age', y='class')
# Out:
# <AxesSubplot:xlabel='age', ylabel='class'>

# %%
sns.boxplot(data=df, x='age', y='class', hue='alive')
# Out:
# <AxesSubplot:xlabel='age', ylabel='class'>

# %%
sns.boxplot(data=df, x='fare', y='alive')
# Out:
# <AxesSubplot:xlabel='fare', ylabel='alive'>

# %%
sns.boxplot(data=df, x='fare', y='alive', order=['yes','no'])
# Out:
# <AxesSubplot:xlabel='fare', ylabel='alive'>

# %%
sns.boxplot(data=df[['age','fare']], orient='v')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df[['age','fare']], orient='h')
# Out:
# <AxesSubplot:>

# %%
df=sns.load_dataset('titanic')
sns.violinplot(x=df['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.violinplot(data=df, x='age', y='class')
# Out:
# <AxesSubplot:xlabel='age', ylabel='class'>

# %%
sns.violinplot(data=df, x='class', y='age', hue='alive')
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
sns.violinplot(data=df, x='deck', y='age', hue='alive', split=True)
# Out:
# <AxesSubplot:xlabel='deck', ylabel='age'>

# %%
sns.violinplot(data=df, x='age', y='alive', cut=0)
# Out:
# <AxesSubplot:xlabel='age', ylabel='alive'>

# %%
sns.violinplot(data=df, x='age', y='alive', bw=.15)
# Out:
# <AxesSubplot:xlabel='age', ylabel='alive'>

# %%
sns.violinplot(data=df, x='age', y='embark_town', inner='stick')
# Out:
# <AxesSubplot:xlabel='age', ylabel='embark_town'>

# %%
sns.violinplot(data=df, x='age', y='embark_town', scale='count', inner='stick')
# Out:
# <AxesSubplot:xlabel='age', ylabel='embark_town'>

# %%
sns.violinplot(data=df, x='age', y='embark_town', scale='count', cut=0)
# Out:
# <AxesSubplot:xlabel='age', ylabel='embark_town'>

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import pandas as pd

rain = pd.read_csv('kma_data/STCS_강수일수_MNH_20230314153702.csv', encoding='euc-kr')
rain['지점정보']=rain['지점정보']
rain
# Out:
#         지점정보         경도        위도  강수일수
# 0    고산(185)  126.16283  33.29382     6
# 1    부여(236)  126.92079  36.27242    16
# 2    울진(130)  129.41278  36.99176    16
# 3    장흥(260)  126.91951  34.68886    13
# 4    충주(127)  127.95250  36.97045    19
# ..       ...        ...       ...   ...
# 90  고창군(251)  126.69700  35.42661    16
# 91  김해시(253)  128.89075  35.22981    13
# 92   완도(170)  126.70182  34.39590    11
# 93   의성(278)  128.68864  36.35610    17
# 94   보령(235)  126.55744  36.32724    18
#
# [95 rows x 4 columns]

# %%
import matplotlib as mpl
# Add every font at the specified location
font_dir = ['./fonts']
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname=font).get_name())
    mpl.font_manager.fontManager.addfont(font)

# %%
# Set font family globally
mpl.rcParams['font.family'] = 'Noto Sans KR'
print(mpl.rcParams['font.family'])
# Out:
# ['Noto Sans KR']

# %%
sns.countplot(data=rain, y='강수일수')
# Out:
# <AxesSubplot:xlabel='count', ylabel='강수일수'>

# %%
north_rain = pd.read_csv('datas/STCS_북한기후평년값_MNH_20230314162345.csv', encoding='UTF-8')
north_rain
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2268\3306007189.py in <module>
# ----> 1 north_rain = pd.read_csv('datas/STCS_북한기후평년값_MNH_20230314162345.csv', encoding='UTF-8')
#       2 north_rain
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
